# %% [markdown]
# ### 1. Importar bibliotecas

# %%
import numpy as np
from tensorflow import keras

# %% [markdown]
# ### 2. Preparar dados (arrays numpy)

# %%
import numpy as np
from sklearn.model_selection import train_test_split

NUM_TO_GENERATE =10

# Gerar 100 pontos aleatórios começando em -1
# (valores entre -1 e 10, por exemplo)
np.random.seed(42)  # reprodutibilidade
x = np.random.uniform(-1.0, 10.0, NUM_TO_GENERATE).astype(float)
y = 2*x -1 #assumimos já conhecer a função, apenas para validação. A rede neural deverá estimar esta função (descobrir o padrão a partir dos dados)

# Separar treino (70%) e teste (30%)
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.3, random_state=42
)

# Verificar tamanhos
print("Treino:", x_train.shape, y_train.shape)
print("Teste:", x_test.shape, y_test.shape)
# Out:
# Treino: (7,) (7,)
# Teste: (3,) (3,)

# %% [markdown]
# ### 3. Conferindo os tipos antes de injetar na arquitetura da rede neural

# %%
print(type(x))
print(type(y))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# ### 4. Define arquitetura sequencial para um neurônio na única camada escondida (1), otimizador gradiente descendente estocástico e função de perda erro médio quadrático (mse)

# %%
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ### 5. Treinar a rede (já irá separar em conjunto de treino e validação)

# %%
model.fit(x, y, epochs=100)

# %% [markdown]
# <font color='blue'>Questão 5.1: qual o valor inicial e final da função de perda?</font>

# %%
y_pred = model.predict(np.array([15.0]))

# %% [markdown]
# <font color='blue'>Questão 5.2: qual o valor da predição para x = 15.0? qual o erro percentual em relação ao valor esperado?</font>

# %% [markdown]
# ### Registrando o experimento no TENSORBOARD, para visualizar curvas de treinamento (treino e validação)

# %%
import tensorflow as tf
import datetime

# 1. Definir o diretório de logs
log_dir = "/content/logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# 2. Criar o callback do TensorBoard
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# %% [markdown]
# ### Treinar rede com callback do tensorboard

# %%
# 3. Treinar o modelo com o callback
model.fit(
    x_train, y_train,
    epochs=100,
    validation_data=(x_test, y_test),
    callbacks=[tensorboard_callback]
)

# %%
#%load_ext tensorboard
#%tensorboard --logdir=/content/logs/fit/

# %% [markdown]
# <font color='blue'>Faça uma predição para o valor 20.0. Qual o resultado obtido e o erro para o valor esperado?</font>

# %%
#y_pred = model.predict(np.array([20.0]))
#print(y_pred)

# %% [markdown]
# <font color='blue'>Aumente o tamanho do vetor x para 100 amostras (NUM_TO_GENERATE) e retreine o modelo, fazendo nova predição para o valor 20. Observa algo diferente?</font>

# %% [markdown]
# <font color='blue'>Agora, retreine com diferentes otimizadores. Ver os possíveis na lista de hiperparâmetros consultando a documentação keras. Para cada um observe se muda algo no tempo de treino, valor de perda final e forma da curva de treino e validação</font>

# %% [markdown]
# <font color='blue'>Deixe o otimizador fixo conforme sua escolha acima, e agora altere as funções de perda (loss), conforme documentação. Salve os resultados e discuta abaixo o que observou</font>
